# %%
import pandas as pd

# %%
test= pd.read_csv("loan-train - Copy.csv")

# %%
test
# Out:
#       Loan_ID  Gender Married Dependents     Education  CIBIL Self_Employed  \
# 0    LP001002    Male      No          0      Graduate   5849            No
# 1    LP001003    Male     Yes          1      Graduate   4583            No
# 2    LP001005    Male     Yes          0      Graduate   3000           Yes
# 3    LP001006    Male     Yes          0  Not Graduate   2583            No
# 4    LP001008    Male      No          0      Graduate   6000            No
# ..        ...     ...     ...        ...           ...    ...           ...
# 609  LP002978  Female      No          0      Graduate   2900            No
# 610  LP002979    Male     Yes         3+      Graduate   4106            No
# 611  LP002983    Male     Yes          1      Graduate   8072            No
# 612  LP002984    Male     Yes          2      Graduate   7583            No
# 613  LP002990  Female      No          0      Graduate   4583           Yes
#
# ...

# %%
test["CIBIL"]=test["CIBIL"]/8.5

# %%
test
# Out:
#       Loan_ID  Gender Married Dependents     Education       CIBIL  \
# 0    LP001002    Male      No          0      Graduate  688.117647
# 1    LP001003    Male     Yes          1      Graduate  539.176471
# 2    LP001005    Male     Yes          0      Graduate  352.941176
# 3    LP001006    Male     Yes          0  Not Graduate  303.882353
# 4    LP001008    Male      No          0      Graduate  705.882353
# ..        ...     ...     ...        ...           ...         ...
# 609  LP002978  Female      No          0      Graduate  341.176471
# 610  LP002979    Male     Yes         3+      Graduate  483.058824
# 611  LP002983    Male     Yes          1      Graduate  949.647059
# 612  LP002984    Male     Yes          2      Graduate  892.117647
# 613  LP002990  Female      No          0      Graduate  539.176471
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0              No             5849                0.0         NaN
# ...

# %%
test.to_csv("loan-train - Copy.csv")
